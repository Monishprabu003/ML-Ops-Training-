# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/content/logistic_regression_dataset.csv')

df.head()
# Out:
#    Aptitude_Score  First_Round_Cleared
# 0              35                    0
# 1              42                    0
# 2              50                    0
# 3              55                    0
# 4              60                    0

# %%
plt.scatter(df.Aptitude_Score,
            df.First_Round_Cleared,
            marker='+',
            color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df[['Aptitude_Score']],
    df.First_Round_Cleared,
    train_size=0.8
)

# %%
X_test
# Out:
#     Aptitude_Score
# 38              93
# 35              87
# 18              88
# 0               35
# 32              81
# 8               68
# 14              80
# 20              45

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     Aptitude_Score
# 38              93
# 35              87
# 18              88
# 0               35
# 32              81
# 8               68
# 14              80
# 20              45

# %%
y_predicted = model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[4.04121181e-14, 1.00000000e+00],
#        [3.01281222e-11, 1.00000000e+00],
#        [1.00011111e-11, 1.00000000e+00],
#        [1.00000000e+00, 4.13957257e-15],
#        [2.25173798e-08, 9.99999977e-01],
#        [3.65077029e-02, 9.63492297e-01],
#        [6.78332034e-08, 9.99999932e-01],
#        [1.00000000e+00, 2.54800585e-10]])

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
y_predicted
# Out:
# array([1, 1, 1, 0, 1, 1, 1, 0])

# %%
X_test
# Out:
#     Aptitude_Score
# 38              93
# 35              87
# 18              88
# 0               35
# 32              81
# 8               68
# 14              80
# 20              45

# %%
model.coef_
# Out:
# array([[1.1027644]])

# %%
model.intercept_
# Out:
# array([-71.71493772])

# %%
import math

def sigmoid(x):
    return 1 / (1 + math.exp(-x))

# %%
def prediction_function(score):

    z = 0.1 * score - 5

    y = sigmoid(z)

    return y
